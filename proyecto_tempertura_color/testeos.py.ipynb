# %% [markdown]
# # Temperatura del color

# %% [markdown]
# ###  Gestion de la PiCam

# %%
import picamera
import time

camera.close()
camera = picamera.PiCamera()
camera.resolution = (640, 480)
camera.start_preview()
time.sleep(2)
camera.capture("tasa2.jpg", resize=(640,480))
camera.stop_preview()
camera.close()

# %%
ls
# Out:
# tasa.jpg  test1.py  testeos.py.ipynb

# %%
kelvin_table = {
    1000: (255, 56, 0),
    1100: (255, 71, 0),
    1200: (255, 83, 0),
    1300: (255, 93, 0),
    1400: (255, 101, 0),
    1500: (255, 109, 0),
    1600: (255, 115, 0),
    1700: (255, 121, 0),
    1800: (255, 126, 0),
    1900: (255, 131, 0),
    2000: (255, 138, 18),
    2100: (255, 142, 33),
    2200: (255, 147, 44),
    2300: (255, 152, 54),
    2400: (255, 157, 63),
    2500: (255, 161, 72),
    2600: (255, 165, 79),
    2700: (255, 169, 87),
    2800: (255, 173, 94),
    2900: (255, 177, 101),
    3000: (255, 180, 107),
    3100: (255, 184, 114),
    3200: (255, 187, 120),
    3300: (255, 190, 126),
    3400: (255, 193, 132),
    3500: (255, 196, 137),
    3600: (255, 199, 143),
    3700: (255, 201, 148),
    3800: (255, 204, 153),
    3900: (255, 206, 159),
    4000: (255, 209, 163),
    4100: (255, 211, 168),
    4200: (255, 213, 173),
    4300: (255, 215, 177),
    4400: (255, 217, 182),
    4500: (255, 219, 186),
    4600: (255, 221, 190),
    4700: (255, 223, 194),
    4800: (255, 225, 198),
    4900: (255, 227, 202),
    5000: (255, 228, 206),
    5100: (255, 230, 210),
    5200: (255, 232, 213),
    5300: (255, 233, 217),
    5400: (255, 235, 220),
    5500: (255, 236, 224),
    5600: (255, 238, 227),
    5700: (255, 239, 230),
    5800: (255, 240, 233),
    5900: (255, 242, 236),
    6000: (255, 243, 239),
    6100: (255, 244, 242),
    6200: (255, 245, 245),
    6300: (255, 246, 247),
    6400: (255, 248, 251),
    6500: (255, 249, 253),
    6600: (254, 249, 255),
    6700: (252, 247, 255),
    6800: (249, 246, 255),
    6900: (247, 245, 255),
    7000: (245, 243, 255),
    7100: (243, 242, 255),
    7200: (240, 241, 255),
    7300: (239, 240, 255),
    7400: (237, 239, 255),
    7500: (235, 238, 255),
    7600: (233, 237, 255),
    7700: (231, 236, 255),
    7800: (230, 235, 255),
    7900: (228, 234, 255),
    8000: (227, 233, 255),
    8100: (225, 232, 255),
    8200: (224, 231, 255),
    8300: (222, 230, 255),
    8400: (221, 230, 255),
    8500: (220, 229, 255),
    8600: (218, 229, 255),
    8700: (217, 227, 255),
    8800: (216, 227, 255),
    8900: (215, 226, 255),
    9000: (214, 225, 255),
    9100: (212, 225, 255),
    9200: (211, 224, 255),
    9300: (210, 223, 255),
    9400: (209, 223, 255),
    9500: (208, 222, 255),
    9600: (207, 221, 255),
    9700: (207, 221, 255),
    9800: (206, 220, 255),
    9900: (205, 220, 255),
    10000: (207, 218, 255),
    10100: (207, 218, 255),
    10200: (206, 217, 255),
    10300: (205, 217, 255),
    10400: (204, 216, 255),
    10500: (204, 216, 255),
    10600: (203, 215, 255),
    10700: (202, 215, 255),
    10800: (202, 214, 255),
    10900: (201, 214, 255),
    11000: (200, 213, 255),
    11100: (200, 213, 255),
    11200: (199, 212, 255),
    11300: (198, 212, 255),
    11400: (198, 212, 255),
    11500: (197, 211, 255),
    11600: (197, 211, 255),
    11700: (197, 210, 255),
    11800: (196, 210, 255),
    11900: (195, 210, 255),
    12000: (195, 209, 255)}

# %% [markdown]
# Usando OpenCV para trabajar la imagen

# %%
# %matplotlib inline
'''
import matplotlib.pyplot as plt
import io
import time
import picamera
import cv2
import numpy as np

# Create the in-memory stream
stream = io.BytesIO()
with picamera.PiCamera() as camera:
    camera.start_preview()
    time.sleep(2)
    camera.capture(stream, format='jpeg')
# Construct a numpy array from the stream
data = np.fromstring(stream.getvalue(), dtype=np.uint16)
# "Decode" the image from the array, preserving colour
image = cv2.imdecode(data, 1)
# OpenCV returns an array with data in BGR order. If you want RGB instead
# use the following...
image = image[:, :, ::-1]

plt.imshow(image)
plt.title('Temperatura Color')
plt.show()
'''
# Out:
# '\nimport matplotlib.pyplot as plt\nimport io\nimport time\nimport picamera\nimport cv2\nimport numpy as np\n\n# Create the in-memory stream\nstream = io.BytesIO()\nwith picamera.PiCamera() as camera:\n    camera.start_preview()\n    time.sleep(2)\n    camera.capture(stream, format=\'jpeg\')\n# Construct a numpy array from the stream\ndata = np.fromstring(stream.getvalue(), dtype=np.uint16)\n# "Decode" the image from the array, preserving colour\nimage = cv2.imdecode(data, 1)\n# OpenCV returns an array with data in BGR order. If you want RGB instead\n# use the following...\nimage = image[:, :, ::-1]\n\nplt.imshow(image)\nplt.title(\'Temperatura Color\')\nplt.show()\n'

# %%
import colour

kelvin_list = [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900,
               2000, 2100, 2200, 2300, 2400, 2500, 2600, 2700, 2800, 2900,
               3000, 3100, 3200, 3300, 3400, 3500, 3600, 3700, 3800, 3900,
               4000, 4100, 4200, 4300, 4400, 4500, 4600, 4700, 4800, 4900,
               5000, 5100, 5200, 5300, 5400, 5500, 5600, 5700, 5800, 5900,
               6000, 6100, 6200, 6300, 6400, 6500, 6600, 6700, 6800, 6900,
               7000, 7100, 7200, 7300, 7400, 7500, 7600, 7700, 7800, 7900,
               8000, 8100, 8200, 8300, 8400, 8500, 8600, 8700, 8800, 8900,
               9000, 9100, 9200, 9300, 9400, 9500, 9600, 9700, 9800, 9900,
               10000, 10100, 10200, 10300, 10400, 10500, 10600, 10700, 10800, 10900,
               11000, 11100, 11200, 11300, 11400, 11500, 11600, 11700, 11800, 11900,
               12000]

#kelvin_list

# %%
from PIL import Image

image = Image.open("tasa2.jpg")
file_type = '.jpg'
quality_factor = 2   # higher values means lesser quality. because.

for i in range(0, len(kelvin_list), quality_factor):
    kelvin_value = kelvin_list[i]
    print('Working on Kelvin value: ', kelvin_value)
    temp = kelvin_table[kelvin_value]
    r, g, b = temp
    color_matrix = (r / 255.0, 0.0, 0.0, 0.0, 0.0, g / 255.0, 0.0, 0.0, 0.0, 0.0, b / 255.0, 0.0)
    new_image = image.convert('RGB', color_matrix)
    kelvin_list_string = str(kelvin_list[i])
    seq = kelvin_list_string + file_type
    new_image.save(seq, "JPEG", quality=80, optimize=True, progressive=False)
# Out:
# Working on Kelvin value:  1000
# Working on Kelvin value:  1200
# Working on Kelvin value:  1400
# Working on Kelvin value:  1600
# Working on Kelvin value:  1800
# Working on Kelvin value:  2000
# Working on Kelvin value:  2200
# Working on Kelvin value:  2400
# Working on Kelvin value:  2600
# Working on Kelvin value:  2800
# Working on Kelvin value:  3000
# Working on Kelvin value:  3200
# Working on Kelvin value:  3400
# Working on Kelvin value:  3600
# Working on Kelvin value:  3800
# Working on Kelvin value:  4000
# Working on Kelvin value:  4200
# Working on Kelvin value:  4400
# Working on Kelvin value:  4600
# Working on Kelvin value:  4800
# Working on Kelvin value:  5000
# Working on Kelvin value:  5200
# Working on Kelvin value:  5400
# Working on Kelvin value:  5600
# Working on Kelvin value:  5800
# Working on Kelvin value:  6000
# Working on Kelvin value:  6200
# Working on Kelvin value:  6400
# Working on Kelvin value:  6600
# Working on Kelvin value:  6800
# Working on Kelvin value:  7000
# Working on Kelvin value:  7200
# Working on Kelvin value:  7400
# Working on Kelvin value:  7600
# Working on Kelvin value:  7800
# Working on Kelvin value:  8000
# Working on Kelvin value:  8200
# Working on Kelvin value:  8400
# Working on Kelvin value:  8600
# Working on Kelvin value:  8800
# Working on Kelvin value:  9000
# Working on Kelvin value:  9200
# Working on Kelvin value:  9400
# Working on Kelvin value:  9600
# Working on Kelvin value:  9800
# Working on Kelvin value:  10000
# Working on Kelvin value:  10200
# Working on Kelvin value:  10400
# Working on Kelvin value:  10600
# Working on Kelvin value:  10800
# Working on Kelvin value:  11000
# Working on Kelvin value:  11200
# Working on Kelvin value:  11400
# Working on Kelvin value:  11600
# Working on Kelvin value:  11800
# Working on Kelvin value:  12000
